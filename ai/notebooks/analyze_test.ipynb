# %%
import sys

print("python 버전:", sys.version)
print("python 버전:", sys.executable)
# Out:
# python 버전: 3.11.16 | packaged by Anaconda, Inc. | (main, Aug 27 2026, 14:36:16) [MSC v.1942 64 bit (AMD64)]
# python 버전: c:\Users\user\anaconda3\envs\careerpulse\python.exe
